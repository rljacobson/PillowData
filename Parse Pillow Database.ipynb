# %%
# %matplotlib inline

import io
from collections import OrderedDict
import datetime
import pytz

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
from IPython.display import Markdown, display, HTML

def printhtml(string):
    display(HTML(string))

def printmd(string):
    display(Markdown(string))

# %% [markdown]
# # Parse the file into DataFrames

# %%
tables = ['ZPILLOWUSER', 'ZSLEEPNOTE', 'Z_2SLEEPSESSION', 'ZSLEEPSESSION', 'ZSLEEPSTAGEDATAPOINT', 'ZSNOOZELAB', 'ZSOUNDDATAPOINT', 'Z_PRIMARYKEY', 'Z_METADATA', 'Z_MODELCACHE', 'Y_UBMETA', 'Y_UBRANGE', 'Y_UBKVS']
# tables = ['ZSLEEPSESSION', 'ZSLEEPSTAGEDATAPOINT']

# %%
def getDictFromString(string):
    tokens = string.split()
    # tokens.reverse()
    row = OrderedDict()
    
    while tokens:
        # Values may be multiple words. We build up a value until we reach a 
        # separator. The value is then the concatenation of the reverse of the list.
        value_parts = [tokens.pop()]
        value_part_or_sep = tokens.pop() # ' -> '
        while value_part_or_sep != '->':
            value_parts.append(value_part_or_sep)
            value_part_or_sep = tokens.pop()
        value_parts.reverse()
        
        # Keys are one word.
        key = tokens.pop()
        row[key] = ' '.join(value_parts)
        
    return row

# %%
filename = 'PillowData.txt'
reading_table = None
dataframes = {}
rows = []
count = 0

with open(filename) as file:
    for line in file:
#         count += 1
#         if count >2:
#             break
        
        line = line.strip()
        
        # if we are at a new table heading
        if line in tables:
            # If we are finished reading the last table
            if reading_table:
                dataframes[reading_table] = pd.DataFrame(rows)
            
            # record which table we are reading. 
            reading_table = line
            # Init the list of rows.
            rows = []
            continue
            
        elif line == '':
            # EOF has extra newline, conveniently signalling that we need to 
            # make the dataframe for the last table.
            dataframes[reading_table] = pd.DataFrame(rows)
            del rows
            break
        
        rows.append(getDictFromString(line))

# Reverse the order of the columns in each dataframe.
for k, v in dataframes.items():
    dataframes[k] = v.iloc[:, ::-1]


# Convert each column to numeric datatype if possible.
for df in dataframes.values():
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(df[col])
        except:
            pass

# %%
df_sessions = dataframes['ZSLEEPSESSION']
df_stages = dataframes['ZSLEEPSTAGEDATAPOINT']
df_audio = dataframes['ZSOUNDDATAPOINT']
df_session_notes = dataframes['Z_2SLEEPSESSION']
df_notes = dataframes['ZSLEEPNOTE']

# %% [markdown]
# # Deal with timestamps
#
# Timestamps are dates and times, but with incorrect years.

# %%
def makeDateTime(timestamp, year=2018):
    return datetime.datetime.fromtimestamp(timestamp, pytz.timezone('US/Eastern')).replace(year=year)

df_stages.sort_values('ZTIMESTAMP', inplace=True)
df_stages['ZTIMESTAMP'] = df_stages['ZTIMESTAMP'].apply(makeDateTime)
df_sessions['ZSTARTTIME'] = df_sessions['ZSTARTTIME'].apply(makeDateTime)
df_sessions['ZENDTIME'] = df_sessions['ZENDTIME'].apply(makeDateTime)
df_audio.sort_values('ZTIMESTAMP', inplace=True)
df_audio['ZTIMESTAMP'] = df_audio['ZTIMESTAMP'].apply(makeDateTime)

# %% [markdown]
# # Plotting

# %%
audio_color = 'purple'
colors=['dodgerblue', 'mediumaquamarine', 'deeppink', 'darkorange']

def plotSession(session):
    df = df_stages[df_stages['ZSLEEPSESSION']==session]
    dfa = df_audio[df_audio['ZSLEEPSESSION']==session]

    x = df['ZTIMESTAMP'].values
    y = df['ZSLEEPSTAGE'].values

    # Plot initialization boilerplate
    plt.close('all')
    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(111)

    # First plot the audio intervals.
    for row in dfa.iterrows():
        ax.bar(row[1]['ZTIMESTAMP'], 4, 5*np.timedelta64(row[1]['ZDURATION'], 's')/np.timedelta64(1, 'D') , 0, align='edge', color=audio_color)


    # Now plot the intervals for the different stages.
    left = x[0]
    width = datetime.timedelta(0)
    bottom = y[0]
    height = 1
    for i, val in enumerate(y):
        if val != bottom:
            box = ax.bar(left, height, width, bottom, align='edge', color=colors[int(bottom)])
            left = x[i]
            bottom = val
            width = datetime.timedelta(0)
        # The division below converts to a fraction of a day which is expected by matplotlib for
        # some reason. Basically, matplotlib doesn't support timedeltas as widths.
        width = (x[i] - left)/np.timedelta64(1, 'D') 

    # finish last box:
    box = ax.bar(left, height, width, bottom, align='edge', color=colors[int(bottom)])

    ax.set_yticks([0, 1, 2, 3, 4])
    ax.set_yticklabels(['', 'Deep', 'Light', 'REM', 'Awake'])

    plt.tick_params(
        axis='y',          # changes apply to the x-axis
        which='minor',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False)

    # Format the xticklabels.
    ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%I:%M %p', tz=pytz.timezone('US/Eastern')))

    fig.tight_layout()
    output = io.StringIO()
    plt.savefig(output, format="svg")
    plt.close()
    # The first 214 characters are unnecessary header material. The last character is \n.
    return output.getvalue()[214:-1]

# %%
def plotStackedPercentages(*args):
    # Plot initialization boilerplate
    plt.close('all')
    fig = plt.figure(figsize=(10, 1))
    ax = fig.add_subplot(111)
    
    height = 1
    left = 0
    bottom = 0
    
    for i, c in enumerate(reversed(colors)):
        width = args[i]
        ax.bar(left, height, width, bottom, align='edge', color=c)
        left += width
        
    plt.axis('off')
    ax.set_facecolor(None)
    
    fig.tight_layout()
    output = io.StringIO()
    plt.savefig(output, format="svg", transparent=True)
    plt.close()
    # The first 214 characters are unnecessary header material. The last character is \n.
    return output.getvalue()[214:-1]

# %% [markdown]
# # Summary Data Table

# %%
moods = ['Bad', 'Not so good', 'OK', 'Good', 'Great']
mood_emojis = ['😧', '🙁', '😐', '🙂', '😀']

# %%
def roundTimedelta(t):
    if hasattr(t, 'total_seconds'):
        # Must be datetime.timedelta or np.timedelta64 or equivalent.
        return datetime.timedelta(seconds=round(t.total_seconds()))
    # Must be float or equivalent.
    return datetime.timedelta(seconds=round(t))

# %%
def showSession(row):
    
    
    session = row['Z_PK']
    when = row['ZSTARTTIME'].strftime('%A, %B %-d, %Y at %-I:%M {%p}').format(AM='a.m.', PM='p.m.')
    total_time = row['ZENDTIME'] - row['ZSTARTTIME']
    duration = str(roundTimedelta(total_time))
    time_to_sleep = roundTimedelta(row['ZTIMEAWAKE'])
    asleep = roundTimedelta(total_time.total_seconds() - row['ZTIMEAWAKE'])
    quality = row['ZSLEEPQUALITY']
    mood = row['ZWAKEUPMOOD'] - 1
    mood_string = '{emoji} {description}'.format(emoji=mood_emojis[mood], description=moods[mood])
    
    rem = round(roundTimedelta(row['ZTIMEINREMSLEEP'])/total_time*100)
    light = round(roundTimedelta(row['ZTIMEINLIGHTSLEEP'])/total_time*100)
    deep = round(roundTimedelta(row['ZTIMEINDEEPSLEEP'])/total_time*100)
    awake = 100-(rem+light+deep)
    
    # Get notes.
    notes = []
    for note in df_session_notes[df_session_notes['Z_3SLEEPSESSION']==session].iterrows():
        note_pk = note[1]['Z_2SLEEPNOTE']
        # In classic parsimonious Pandas style, this looks up the text for a note code.
        note_text = df_notes[df_notes['Z_PK']==note_pk].iloc[0].at['ZCONTENTTEXT']
        notes.append(note_text)
    
    # Display.
    # Date
#     printmd('<div style="text-align: center">**{when}**</div>'.format(when=when))
    printmd('# {when}'.format(when=when))
    
    # Sleep stages graph
    stages_graph = plotSession(session)
    printhtml(stages_graph)
    
    # Summary Information Table
    table = """|  | | | |
|------------:|:-----|----:|:----|
| Time in bed | {duration} | Sleep quality |{quality:.0%} |
| Time asleep | {asleep} | Mood | {mood} |
| Time to sleep | {time_to_sleep} | Notes | {notes}&nbsp; |"""
    printmd(table.format(when=when,
                         duration=duration, 
                         asleep=asleep, 
                         time_to_sleep=time_to_sleep,
                         quality=quality, 
                         mood=mood_string,
                         notes='\n'.join(notes)
                        ))
    
    
    # Stacked percentages plot.
    printhtml(plotStackedPercentages(awake, rem, light, deep))

    # Table of percentages.
    colored_dots = ['<font style="color:{color}">\u2B24</font>'.format(color=c) for c in colors]
    table_percents = """| | | | |
|-----------:|-----:|----:|----:|
| Awake | {awake}%{dota} | REM | {rem}%{dotr} |
| Light Sleep | {light}%{dotl} | Deep Sleep | {deep}%{dotd} |"""
    printmd(table_percents.format(awake=awake,
                                  rem=rem,
                                  light=light,
                                  deep=deep,
                                  dotd=colored_dots[0],
                                  dotl=colored_dots[1],
                                  dotr=colored_dots[2],
                                  dota=colored_dots[3]
                                 ))

# %%
for row in df_sessions.iterrows():   
    showSession(row[1])
# Out:
# # Thursday, April 26, 2018 at 11:11 p.m.
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:#f0f0f0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 47.3 263.7
# L 709.2 263.7
# L 709.2 10.8
# L 47.3 10.8
# z
# " style="fill:#f0f0f0;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p075607f3d0)" d="M 61.08335 263.7
# L 61.08335 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_2"/>
#      <g id="text_1">
#       <!-- 11:00 PM -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 11.71875 12.40625
# L 22.015625 12.40625
# L 22.015625 0
# L 11.71875 0
# z
# M 11.71875 51.703125
# L 22.015625 51.703125
# L 22.015625 39.3125
# L 11.71875 39.3125
# z
# " id="DejaVuSans-3a"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#        <path id="DejaVuSans-20"/>
#        <path d="M 19.671875 64.796875
# L 19.671875 37.40625
# L 32.078125 37.40625
# Q 38.96875 37.40625 42.71875 40.96875
# Q 46.484375 44.53125 46.484375 51.125
# Q 46.484375 57.671875 42.71875 61.234375
# Q 38.96875 64.796875 32.078125 64.796875
# z
# M 9.8125 72.90625
# L 32.078125 72.90625
# Q 44.34375 72.90625 50.609375 67.359375
# Q 56.890625 61.8125 56.890625 51.125
# Q 56.890625 40.328125 50.609375 34.8125
# Q 44.34375 29.296875 32.078125 29.296875
# L 19.671875 29.296875
# L 19.671875 0
# L 9.8125 0
# z
# " id="DejaVuSans-50"/>
#        <path d="M 9.8125 72.90625
# L 24.515625 72.90625
# L 43.109375 23.296875
# L 61.8125 72.90625
# L 76.515625 72.90625
# L 76.515625 0
# L 66.890625 0
# L 66.890625 64.015625
# L 48.09375 14.015625
# L 38.1875 14.015625
# L 19.390625 64.015625
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-4d"/>
#       </defs>
#       <g transform="translate(37.756006 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-50"/>
#        <use x="380.273438" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p075607f3d0)" d="M 149.236237 263.7
# L 149.236237 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#       </defs>
#       <g transform="translate(125.503424 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p075607f3d0)" d="M 237.389123 263.7
# L 237.389123 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 01:00 AM -->
#       <g transform="translate(213.65631 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p075607f3d0)" d="M 325.542009 263.7
# L 325.542009 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 02:00 AM -->
#       <g transform="translate(301.809197 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p075607f3d0)" d="M 413.694896 263.7
# L 413.694896 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53.9
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 6:49:34 | Sleep quality |58% |
# | Time asleep | 6:34:34 | Mood | 🙁 Not so good |
# | Time to sleep | 0:15:00 | Notes | &nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#pd0d5af6f63)" d="M 51.971591 47.7
# L 158.38 47.7
# L 158.38 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#pd0d5af6f63)" d="M 158.38 47.7
# L 214.713864 47.7
# L 214.713864 13.901361
# L 158.38 13.901361
# z
# " style="fill:#ff1493;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#pd0d5af6f63)" d="M 214.713864 47.7
# L 358.678182 47.7
# L 358.678182 13.901361
# L 214.713864 13.901361
# z
# " style="fill:#66cdaa;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#pd0d5af6f63)" d="M 358.678182 47.7
# L 677.903409 47.7
# L 677.903409 13.901361
# L 358.678182 13.901361
# z
# " style="fill:#1e90ff;"/>
#    </g>
#   </g>
#  </g>
#  <defs>
#   <clipPath id="pd0d5af6f63">
#    <rect height="35.488571" width="688.525" x="20.675" y="12.211429"/>
#   </clipPath>
#  </defs>
# </svg>
# | | | | |
# |-----------:|-----:|----:|----:|
# | Awake | 17%<font style="color:darkorange">⬤</font> | REM | 9%<font style="color:deeppink">⬤</font> |
# | Light Sleep | 23%<font style="color:mediumaquamarine">⬤</font> | Deep Sleep | 51%<font style="color:dodgerblue">⬤</font> |
# # Friday, April 27, 2018 at 11:54 p.m.
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:#f0f0f0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 47.3 263.7
# L 709.2 263.7
# L 709.2 10.8
# L 47.3 10.8
# z
# " style="fill:#f0f0f0;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p50a535d3e1)" d="M 82.937613 263.7
# L 82.937613 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_2"/>
#      <g id="text_1">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 11.71875 12.40625
# L 22.015625 12.40625
# L 22.015625 0
# L 11.71875 0
# z
# M 11.71875 51.703125
# L 22.015625 51.703125
# L 22.015625 39.3125
# L 11.71875 39.3125
# z
# " id="DejaVuSans-3a"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#        <path id="DejaVuSans-20"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#        <path d="M 9.8125 72.90625
# L 24.515625 72.90625
# L 43.109375 23.296875
# L 61.8125 72.90625
# L 76.515625 72.90625
# L 76.515625 0
# L 66.890625 0
# L 66.890625 64.015625
# L 48.09375 14.015625
# L 38.1875 14.015625
# L 19.390625 64.015625
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-4d"/>
#       </defs>
#       <g transform="translate(59.204801 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p50a535d3e1)" d="M 147.327639 263.7
# L 147.327639 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 01:00 AM -->
#       <g transform="translate(123.594827 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p50a535d3e1)" d="M 211.717665 263.7
# L 211.717665 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 02:00 AM -->
#       <g transform="translate(187.984852 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p50a535d3e1)" d="M 276.107691 263.7
# L 276.107691 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53.90625 64.015625 53.90625 55.328125
# Q 53.90625 49.265625 50.4375 45.09375
# Q 46.96875 40.921875 40.578125 39.3125
# z
# " id="DejaVuSans-33"/>
#       </defs>
#       <g transform="translate(252.374878 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-33"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p50a535d3e1)" d="M 340.497716 263.7
# L 340.497716 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 04:00 AM -->
#       <defs>
#        <path d="M 37.796875 64.3125
# L 12.890625 25.390625
# L 37.796875 25.390625
# z
# M 35.203125 72.90625
# L 47.609375 72.90625
# L 47.609375 25.390625
# L 58.015625 25.390625
# L 58.015625 17.1875
# L 47.609375 17.1875
# L 47.609375 0
# L 37.796875 0
# L 37.796875 17.1875
# L 4.890625 17.1875
# L 4.890625 26.703125
# z
# " id="DejaVuSans-34"/>
#       </defs>
#       <g transform="translate(316.
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 9:20:43 | Sleep quality |70% |
# | Time asleep | 8:05:43 | Mood | 🙁 Not so good |
# | Time to sleep | 1:15:00 | Notes | Read a book&nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#pfe22f9fae8)" d="M 51.971591 47.7
# L 133.342727 47.7
# L 133.342727 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#pfe22f9fae8)" d="M 133.342727 47.7
# L 252.269773 47.7
# L 252.269773 13.901361
# L 133.342727 13.901361
# z
# " style="fill:#ff1493;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#pfe22f9fae8)" d="M 252.269773 47.7
# L 440.049318 47.7
# L 440.049318 13.901361
# L 252.269773 13.901361
# z
# " style="fill:#66cdaa;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#pfe22f9fae8)" d="M 440.049318 47.7
# L 677.903409 47.7
# L 677.903409 13.901361
# L 440.049318 13.901361
# z
# " style="fill:#1e90ff;"/>
#    </g>
#   </g>
#  </g>
#  <defs>
#   <clipPath id="pfe22f9fae8">
#    <rect height="35.488571" width="688.525" x="20.675" y="12.211429"/>
#   </clipPath>
#  </defs>
# </svg>
# | | | | |
# |-----------:|-----:|----:|----:|
# | Awake | 13%<font style="color:darkorange">⬤</font> | REM | 19%<font style="color:deeppink">⬤</font> |
# | Light Sleep | 30%<font style="color:mediumaquamarine">⬤</font> | Deep Sleep | 38%<font style="color:dodgerblue">⬤</font> |
# # Saturday, April 28, 2018 at 11:24 p.m.
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:#f0f0f0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 47.3 263.7
# L 704.69258 263.7
# L 704.69258 10.8
# L 47.3 10.8
# z
# " style="fill:#f0f0f0;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p0df045afb2)" d="M 51.502165 263.7
# L 51.502165 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_2"/>
#      <g id="text_1">
#       <!-- 11:00 PM -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 11.71875 12.40625
# L 22.015625 12.40625
# L 22.015625 0
# L 11.71875 0
# z
# M 11.71875 51.703125
# L 22.015625 51.703125
# L 22.015625 39.3125
# L 11.71875 39.3125
# z
# " id="DejaVuSans-3a"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#        <path id="DejaVuSans-20"/>
#        <path d="M 19.671875 64.796875
# L 19.671875 37.40625
# L 32.078125 37.40625
# Q 38.96875 37.40625 42.71875 40.96875
# Q 46.484375 44.53125 46.484375 51.125
# Q 46.484375 57.671875 42.71875 61.234375
# Q 38.96875 64.796875 32.078125 64.796875
# z
# M 9.8125 72.90625
# L 32.078125 72.90625
# Q 44.34375 72.90625 50.609375 67.359375
# Q 56.890625 61.8125 56.890625 51.125
# Q 56.890625 40.328125 50.609375 34.8125
# Q 44.34375 29.296875 32.078125 29.296875
# L 19.671875 29.296875
# L 19.671875 0
# L 9.8125 0
# z
# " id="DejaVuSans-50"/>
#        <path d="M 9.8125 72.90625
# L 24.515625 72.90625
# L 43.109375 23.296875
# L 61.8125 72.90625
# L 76.515625 72.90625
# L 76.515625 0
# L 66.890625 0
# L 66.890625 64.015625
# L 48.09375 14.015625
# L 38.1875 14.015625
# L 19.390625 64.015625
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-4d"/>
#       </defs>
#       <g transform="translate(28.174821 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-50"/>
#        <use x="380.273438" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p0df045afb2)" d="M 114.827978 263.7
# L 114.827978 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#       </defs>
#       <g transform="translate(91.095165 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p0df045afb2)" d="M 178.153791 263.7
# L 178.153791 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 01:00 AM -->
#       <g transform="translate(154.420979 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p0df045afb2)" d="M 241.479605 263.7
# L 241.479605 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 02:00 AM -->
#       <g transform="translate(217.746792 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p0df045afb2)" d="M 304.805418 263.7
# L 304.805418 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.1093
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 9:24:35 | Sleep quality |68% |
# | Time asleep | 7:54:35 | Mood | 😐 OK |
# | Time to sleep | 1:30:00 | Notes | &nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#p532c927e0e)" d="M 51.971591 47.7
# L 152.120682 47.7
# L 152.120682 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p532c927e0e)" d="M 152.120682 47.7
# L 346.159545 47.7
# L 346.159545 13.901361
# L 152.120682 13.901361
# z
# " style="fill:#ff1493;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p532c927e0e)" d="M 346.159545 47.7
# L 515.161136 47.7
# L 515.161136 13.901361
# L 346.159545 13.901361
# z
# " style="fill:#66cdaa;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p532c927e0e)" d="M 515.161136 47.7
# L 677.903409 47.7
# L 677.903409 13.901361
# L 515.161136 13.901361
# z
# " style="fill:#1e90ff;"/>
#    </g>
#   </g>
#  </g>
#  <defs>
#   <clipPath id="p532c927e0e">
#    <rect height="35.488571" width="688.525" x="20.675" y="12.211429"/>
#   </clipPath>
#  </defs>
# </svg>
# | | | | |
# |-----------:|-----:|----:|----:|
# | Awake | 16%<font style="color:darkorange">⬤</font> | REM | 31%<font style="color:deeppink">⬤</font> |
# | Light Sleep | 27%<font style="color:mediumaquamarine">⬤</font> | Deep Sleep | 26%<font style="color:dodgerblue">⬤</font> |
# # Sunday, April 29, 2018 at 10:43 p.m.
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:#f0f0f0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 47.3 263.7
# L 709.2 263.7
# L 709.2 10.8
# L 47.3 10.8
# z
# " style="fill:#f0f0f0;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p5004bd7244)" d="M 98.918365 263.7
# L 98.918365 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_2"/>
#      <g id="text_1">
#       <!-- 11:00 PM -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 11.71875 12.40625
# L 22.015625 12.40625
# L 22.015625 0
# L 11.71875 0
# z
# M 11.71875 51.703125
# L 22.015625 51.703125
# L 22.015625 39.3125
# L 11.71875 39.3125
# z
# " id="DejaVuSans-3a"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#        <path id="DejaVuSans-20"/>
#        <path d="M 19.671875 64.796875
# L 19.671875 37.40625
# L 32.078125 37.40625
# Q 38.96875 37.40625 42.71875 40.96875
# Q 46.484375 44.53125 46.484375 51.125
# Q 46.484375 57.671875 42.71875 61.234375
# Q 38.96875 64.796875 32.078125 64.796875
# z
# M 9.8125 72.90625
# L 32.078125 72.90625
# Q 44.34375 72.90625 50.609375 67.359375
# Q 56.890625 61.8125 56.890625 51.125
# Q 56.890625 40.328125 50.609375 34.8125
# Q 44.34375 29.296875 32.078125 29.296875
# L 19.671875 29.296875
# L 19.671875 0
# L 9.8125 0
# z
# " id="DejaVuSans-50"/>
#        <path d="M 9.8125 72.90625
# L 24.515625 72.90625
# L 43.109375 23.296875
# L 61.8125 72.90625
# L 76.515625 72.90625
# L 76.515625 0
# L 66.890625 0
# L 66.890625 64.015625
# L 48.09375 14.015625
# L 38.1875 14.015625
# L 19.390625 64.015625
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-4d"/>
#       </defs>
#       <g transform="translate(75.591021 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-50"/>
#        <use x="380.273438" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p5004bd7244)" d="M 176.220414 263.7
# L 176.220414 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#       </defs>
#       <g transform="translate(152.487601 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p5004bd7244)" d="M 253.522462 263.7
# L 253.522462 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 01:00 AM -->
#       <g transform="translate(229.78965 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p5004bd7244)" d="M 330.824511 263.7
# L 330.824511 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 02:00 AM -->
#       <g transform="translate(307.091698 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p5004bd7244)" d="M 408.126559 263.7
# L 408.126559 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 7:47:04 | Sleep quality |72% |
# | Time asleep | 7:07:04 | Mood | 😐 OK |
# | Time to sleep | 0:40:00 | Notes | Read a book&nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#p5b58d70dde)" d="M 51.971591 47.7
# L 108.305455 47.7
# L 108.305455 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p5b58d70dde)" d="M 108.305455 47.7
# L 214.713864 47.7
# L 214.713864 13.901361
# L 108.305455 13.901361
# z
# " style="fill:#ff1493;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p5b58d70dde)" d="M 214.713864 47.7
# L 402.493409 47.7
# L 402.493409 13.901361
# L 214.713864 13.901361
# z
# " style="fill:#66cdaa;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p5b58d70dde)" d="M 402.493409 47.7
# L 677.903409 47.7
# L 677.903409 13.901361
# L 402.493409 13.901361
# z
# " style="fill:#1e90ff;"/>
#    </g>
#   </g>
#  </g>
#  <defs>
#   <clipPath id="p5b58d70dde">
#    <rect height="35.488571" width="688.525" x="20.675" y="12.211429"/>
#   </clipPath>
#  </defs>
# </svg>
# | | | | |
# |-----------:|-----:|----:|----:|
# | Awake | 9%<font style="color:darkorange">⬤</font> | REM | 17%<font style="color:deeppink">⬤</font> |
# | Light Sleep | 30%<font style="color:mediumaquamarine">⬤</font> | Deep Sleep | 44%<font style="color:dodgerblue">⬤</font> |
# # Monday, April 30, 2018 at 11:26 p.m.
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:#f0f0f0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 47.3 263.7
# L 709.2 263.7
# L 709.2 10.8
# L 47.3 10.8
# z
# " style="fill:#f0f0f0;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p577fc34fa3)" d="M 127.389294 263.7
# L 127.389294 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_2"/>
#      <g id="text_1">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 11.71875 12.40625
# L 22.015625 12.40625
# L 22.015625 0
# L 11.71875 0
# z
# M 11.71875 51.703125
# L 22.015625 51.703125
# L 22.015625 39.3125
# L 11.71875 39.3125
# z
# " id="DejaVuSans-3a"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#        <path id="DejaVuSans-20"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#        <path d="M 9.8125 72.90625
# L 24.515625 72.90625
# L 43.109375 23.296875
# L 61.8125 72.90625
# L 76.515625 72.90625
# L 76.515625 0
# L 66.890625 0
# L 66.890625 64.015625
# L 48.09375 14.015625
# L 38.1875 14.015625
# L 19.390625 64.015625
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-4d"/>
#       </defs>
#       <g transform="translate(103.656481 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p577fc34fa3)" d="M 218.077419 263.7
# L 218.077419 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 01:00 AM -->
#       <g transform="translate(194.344607 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p577fc34fa3)" d="M 308.765544 263.7
# L 308.765544 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 02:00 AM -->
#       <g transform="translate(285.032731 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p577fc34fa3)" d="M 399.453669 263.7
# L 399.453669 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53.90625 64.015625 53.90625 55.328125
# Q 53.90625 49.265625 50.4375 45.09375
# Q 46.96875 40.921875 40.578125 39.3125
# z
# " id="DejaVuSans-33"/>
#       </defs>
#       <g transform="translate(375.720856 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-33"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p577fc34fa3)" d="M 490.141794 263.7
# L 490.141794 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 04:00 AM -->
#       <defs>
#        <path d="M 37.796875 64.3125
# L 12.890625 25.390625
# L 37.796875 25.390625
# z
# M 35.203125 72.90625
# L 47.609375 72.90625
# L 47.609375 25.390625
# L 58.015625 25.390625
# L 58.015625 17.1875
# L 47.609375 17.1875
# L 47.609375 0
# L 37.796875 0
# L 37.796875 17.1875
# L 4.890625 17.1875
# L 4.890625 26.703125
# z
# " id="DejaVuSans-34"/>
#       </defs>
#       <g transform="translate(4
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 6:38:07 | Sleep quality |75% |
# | Time asleep | 6:23:07 | Mood | 🙂 Good |
# | Time to sleep | 0:15:00 | Notes | &nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#p1dc6d5c48c)" d="M 51.971591 47.7
# L 83.268182 47.7
# L 83.268182 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p1dc6d5c48c)" d="M 83.268182 47.7
# L 170.898636 47.7
# L 170.898636 13.901361
# ...
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#       </defs>
#       <g transform="translate(138.752029 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#paa77717c74)" d="M 244.317891 263.7
# L 244.317891 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 01:00 AM -->
#       <g transform="translate(220.585078 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#paa77717c74)" d="M 326.15094 263.7
# L 326.15094 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 02:00 AM -->
#       <g transform="translate(302.418128 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#paa77717c74)" d="M 407.983989 263.7
# L 407.983989 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53.
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 7:21:12 | Sleep quality |78% |
# | Time asleep | 6:53:52 | Mood | 🙁 Not so good |
# | Time to sleep | 0:27:20 | Notes | Read a book&nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#p54b435ff46)" d="M 51.971591 47.7
# L 83.268182 47.7
# L 83.268182 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p54b435ff46)" d="M 83.268182 47.7
# L 220.973182 47.7
# L 220.973182 13.901361
# L 83.268182 13.901361
# z
# " style="fill:#ff1493;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p54b435ff46)" d="M 220.973182 47.7
# L 377.456136 47.7
# L 377.456136 13.901361
# L 220.973182 13.901361
# z
# " style="fill:#66cdaa;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p54b435ff46)" d="M 377.456136 47.7
# L 677.903409 47.7
# L 677.903409 13.901361
# L 377.456136 13.901361
# z
# " style="fill:#1e90ff;"/>
#    </g>
#   </g>
#  </g>
#  <defs>
#   <clipPath id="p54b435ff46">
#    <rect height="35.488571" width="688.525" x="20.675" y="12.211429"/>
#   </clipPath>
#  </defs>
# </svg>
# | | | | |
# |-----------:|-----:|----:|----:|
# | Awake | 5%<font style="color:darkorange">⬤</font> | REM | 22%<font style="color:deeppink">⬤</font> |
# | Light Sleep | 25%<font style="color:mediumaquamarine">⬤</font> | Deep Sleep | 48%<font style="color:dodgerblue">⬤</font> |
# # Monday, May 7, 2018 at 10:42 p.m.
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:#f0f0f0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 47.3 263.7
# L 709.2 263.7
# L 709.2 10.8
# L 47.3 10.8
# z
# " style="fill:#f0f0f0;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p0bfa963451)" d="M 101.895169 263.7
# L 101.895169 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_2"/>
#      <g id="text_1">
#       <!-- 11:00 PM -->
#       <defs>
#        <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-31"/>
#        <path d="M 11.71875 12.40625
# L 22.015625 12.40625
# L 22.015625 0
# L 11.71875 0
# z
# M 11.71875 51.703125
# L 22.015625 51.703125
# L 22.015625 39.3125
# L 11.71875 39.3125
# z
# " id="DejaVuSans-3a"/>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-30"/>
#        <path id="DejaVuSans-20"/>
#        <path d="M 19.671875 64.796875
# L 19.671875 37.40625
# L 32.078125 37.40625
# Q 38.96875 37.40625 42.71875 40.96875
# Q 46.484375 44.53125 46.484375 51.125
# Q 46.484375 57.671875 42.71875 61.234375
# Q 38.96875 64.796875 32.078125 64.796875
# z
# M 9.8125 72.90625
# L 32.078125 72.90625
# Q 44.34375 72.90625 50.609375 67.359375
# Q 56.890625 61.8125 56.890625 51.125
# Q 56.890625 40.328125 50.609375 34.8125
# Q 44.34375 29.296875 32.078125 29.296875
# L 19.671875 29.296875
# L 19.671875 0
# L 9.8125 0
# z
# " id="DejaVuSans-50"/>
#        <path d="M 9.8125 72.90625
# L 24.515625 72.90625
# L 43.109375 23.296875
# L 61.8125 72.90625
# L 76.515625 72.90625
# L 76.515625 0
# L 66.890625 0
# L 66.890625 64.015625
# L 48.09375 14.015625
# L 38.1875 14.015625
# L 19.390625 64.015625
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-4d"/>
#       </defs>
#       <g transform="translate(78.567826 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-50"/>
#        <use x="380.273438" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p0bfa963451)" d="M 184.238973 263.7
# L 184.238973 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_4"/>
#      <g id="text_2">
#       <!-- 12:00 AM -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-32"/>
#        <path d="M 34.1875 63.1875
# L 20.796875 26.90625
# L 47.609375 26.90625
# z
# M 28.609375 72.90625
# L 39.796875 72.90625
# L 67.578125 0
# L 57.328125 0
# L 50.6875 18.703125
# L 17.828125 18.703125
# L 11.1875 0
# L 0.78125 0
# z
# " id="DejaVuSans-41"/>
#       </defs>
#       <g transform="translate(160.50616 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p0bfa963451)" d="M 266.582776 263.7
# L 266.582776 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_6"/>
#      <g id="text_3">
#       <!-- 01:00 AM -->
#       <g transform="translate(242.849964 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-31"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path clip-path="url(#p0bfa963451)" d="M 348.926579 263.7
# L 348.926579 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_8"/>
#      <g id="text_4">
#       <!-- 02:00 AM -->
#       <g transform="translate(325.193766 274.798438)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-32"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-3a"/>
#        <use x="160.9375" xlink:href="#DejaVuSans-30"/>
#        <use x="224.560547" xlink:href="#DejaVuSans-30"/>
#        <use x="288.183594" xlink:href="#DejaVuSans-20"/>
#        <use x="319.970703" xlink:href="#DejaVuSans-41"/>
#        <use x="388.378906" xlink:href="#DejaVuSans-4d"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path clip-path="url(#p0bfa963451)" d="M 431.270382 263.7
# L 431.270382 10.8
# " style="fill:none;stroke:#cbcbcb;"/>
#      </g>
#      <g id="line2d_10"/>
#      <g id="text_5">
#       <!-- 03:00 AM -->
#       <defs>
#        <path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q
# |  | | | |
# |------------:|:-----|----:|:----|
# | Time in bed | 7:18:20 | Sleep quality |85% |
# | Time asleep | 7:08:20 | Mood | 🙂 Good |
# | Time to sleep | 0:10:00 | Notes | Read a book&nbsp; |
# <svg height="72pt" version="1.1" viewBox="0 0 720 72" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 72
# L 720 72
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path clip-path="url(#ped13c5a30b)" d="M 51.971591 47.7
# L 70.749545 47.7
# L 70.749545 13.901361
# L 51.971591 13.901361
# z
# " style="fill:#ff8c00;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#ped13c5a30b)" d="M 70.749545 47.7
# L 189.676591 47.7
# L 189.676591 13.901361
# L 70.749545 13.901361
# z
# " style="fill:#ff1493;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#ped13c5a30b)" d="M 189.676591 47.7
# L 383.715455 47.7
# L 383.715455 13.901361
# L 189.676591 13.901361
# z
# " style="fill:#66cdaa;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#ped13c5a30b)" d="M 383.715455 47.7
# L 677.903409 47.7
# L 677.903409 13.901361
# L 383.715455 13.901361
# z
# " style="fill:#1e90ff;"/>
#    </g>
#   </g>
#  </g>
#  <defs>
#   <clipPath id="ped13c5a30b">
#    <rect height="35.488571" width="688.525" x="20.675" y="12.211429"/>
#   </clipPath>
#  </defs>
# </svg>
# | | | | |
# |-----------:|-----:|----:|----:|
# | Awake | 3%<font style="color:darkorange">⬤</font> | REM | 19%<font style="color:deeppink">⬤</font> |
# | Light Sleep | 31%<font style="color:mediumaquamarine">⬤</font> | Deep Sleep | 47%<font style="color:dodgerblue">⬤</font> |
